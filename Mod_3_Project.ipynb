# %% [markdown]
# <a href="https://colab.research.google.com/github/surey99/STC510/blob/main/Mod_3_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Module 3 Project -- Basic
#
# Phoenix Crime Breakdown

# %%
import numpy as mp
import matplotlib.pyplot as plt
import pandas as pd
import csv

# %%
crime = pd.read_csv('crimestat (1).csv', quoting=csv.QUOTE_NONE)

# %%
for i, col in enumerate(crime.columns):
    crime.iloc[:, i] = crime.iloc[:, i].str.replace('"', '')

# %%
crime.rename(columns={'"INC NUMBER"': 'INCNUM', '"OCCURRED ON"': 'OCCURRED ON','"OCCURRED TO"': 'OCCURRED TO', '"UCR CRIME CATEGORY"': 'CATEGORY','"100 BLOCK ADDR"': 'ADD', '"ZIP"': 'ZIP','"PREMISE TYPE"': 'PREMISETYPE'}, inplace=True)

# %%
crime
# Out:
#                  INCNUM        OCCURRED ON        OCCURRED TO  \
# 0       201600000052855  11/01/2015  00:00  01/09/2016  00:00
# 1       201600000594484  11/01/2015  00:00                NaN
# 2       201500002102327  11/01/2015  00:00  11/01/2015  09:00
# 3       201500002101405  11/01/2015  00:00  11/01/2015  05:00
# 4       201500002102668  11/01/2015  00:00  11/01/2015  11:50
# ...                 ...                ...                ...
# 131672  201700002027239  11/17/2017  04:15  11/17/2017  04:30
# 131673  201700002025582  11/17/2017  05:00  11/17/2017  09:50
# 131674  201700002024523  11/17/2017  05:34                NaN
# 131675  201700002030009  11/17/2017  05:50  11/17/2017  07:50
# 131676  201700002107372  11/17/2017  06:00  11/30/2017  06:00
#
#                    CATEGORY                       ADD    ZIP  \
# 0       MOTOR VEHICLE THEFT  N 43RD AVE & W CACTUS RD  85029
# 1                      RAPE         13XX E ALMERIA RD  85006
# ...

# %% [markdown]
# Grouping Crime By Zipcode -- Example 85006

# %%
crime[crime.ZIP=='85006']
# Out:
#                  INCNUM        OCCURRED ON        OCCURRED TO  \
# 1       201600000594484  11/01/2015  00:00                NaN
# 44      201600000127791  11/01/2015  06:00  01/19/2016  16:00
# 75      201600000205695  11/01/2015  12:00  02/02/2016  17:40
# 124     201500002104541  11/01/2015  17:10                NaN
# 169     201510000015576  11/02/2015  00:23                NaN
# ...                 ...                ...                ...
# 131301  201700002029378  11/15/2017  00:00                NaN
# 131511  201700002018962  11/16/2017  08:55                NaN
# 131530  201700001887434  11/16/2017  12:00                NaN
# 131553  201700002021225  11/16/2017  15:00  11/16/2017  15:41
# 131622  201700002023363  11/16/2017  21:06                NaN
#
#                    CATEGORY                  ADD    ZIP  \
# 1                      RAPE    13XX E ALMERIA RD  85006
# 44            LARCENY-THEFT  21XX E VIRGINIA AVE  85006
# ...

# %% [markdown]
# Value counts for every Zip Code

# %%
crime.ZIP.value_counts()
# Out:
# 85015    6963
# 85008    6320
# 85009    5513
# 85041    5477
# 85051    5389
#          ...
# 85203       1
# 85266       1
# 85381       1
# 85268       1
# 85212       1
# Name: ZIP, Length: 98, dtype: int64

# %% [markdown]
# Crime in each Zip Code and then broken down by Category of Crime

# %%
crimezip = crime.groupby('ZIP')

# %%
crimezip.CATEGORY.value_counts()
# Out:
# ZIP    CATEGORY
# 85003  LARCENY-THEFT          758
#        DRUG OFFENSE           194
#        BURGLARY               179
#        MOTOR VEHICLE THEFT    128
#        AGGRAVATED ASSAULT     120
#                              ...
# 85395  AGGRAVATED ASSAULT       1
#        RAPE                     1
# 85396  LARCENY-THEFT            2
#        BURGLARY                 1
#        MOTOR VEHICLE THEFT      1
# Name: CATEGORY, Length: 561, dtype: int64
